# %%
import os
from langchain_openai import ChatOpenAI
from langgraph.graph import Graph
from langgraph.prebuilt import create_react_agent
import gradio as gr
from datetime import datetime

# Import tools
from tools.calculator import CalculatorTool
from tools.city_recommender import CityRecommendationTool
from tools.email_tool import EmailItineraryTool
from tools.hotel_search import HotelSearchTool
from tools.user_preferences import UserPreferencesTool
from tools.flight_search import FlightSearchTool
from tools.map_tool import MapPlottingTool
from tools.attractions_tool import CityAttractionsTool
from city_vector_db import CityVectorDB

# %%
def initialize_tools():

    vector_db = CityVectorDB()
    vector_db.load("cities_vector_db")

    tools = [
        UserPreferencesTool(),
        FlightSearchTool(api_key=os.getenv('SERPAPI_API_KEY')),
        MapPlottingTool(),
        EmailItineraryTool(
            smtp_user="h.belagur1980@gmail.com",
            smtp_password=os.getenv('GMAIL_PASSWORD')
        ),
        CityAttractionsTool(),
        HotelSearchTool(api_key=os.getenv('SERPAPI_API_KEY')),
        CalculatorTool(), 
        CityRecommendationTool(vector_db=vector_db)
    ]
    return tools

# %%
tools = initialize_tools()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
system_prompt = f"""You are a helpful travel assistant named Fred.

Follow these steps in order:

1. CITY RECOMMENDATION:
   - Use city_recommendation_tool EXACTLY ONCE to suggest one city
   
2. FLIGHT SEARCH:
   - Use the user's hometown as the departure_airport and the first recommended city as the arrival_airport
   - Ask for specific travel dates (departure and return, if return is not given, get the duration of the trip)
   - Use flight_search_tool with IATA codes
   - Format: {{
       'departure_airport': '[IATA code]',
       'arrival_airport': '[IATA code]',
       'departure_date': 'YYYY-MM-DD',
       'return_date': 'YYYY-MM-DD'  # Optional for one-way flights
   }}

3. HOTEL SEARCH
   - Look for hotels in the recommended city for the dates of the flight (departure and return date) and pick the cheapest one

4. ATTRACTIONS:
   - Once the hotel and flight are selected, use the city_attractions_tool to get the top attractions in the recommended city. Make sure you match the correct formats for the tool

5. CALCULATOR:
   - Use the calculator_tool to sum up the selected flight and hotel costs and also provide the breakdown of the costs   

6. END:
   - Once the user is done with the conversation, thank them and end the conversation
   
Remember that today's date is {datetime.now().strftime('%Y-%m-%d')}. Only search for future dates.
Do not repeat city recommendations unless explicitly asked by the user.

For eg. If the user's name is John Lincoln and they are planning a trip to New York. First, check if John Lincoln has stored preferences using the user_preferences_tool. If not, ask about his travel preferences.
Then using their preferences, recommend a city using the city_recommendation_tool. Ask the user where they are flying from and the dates of travel. Use the flight_search_tool to get the flight details.
Then look for hotels in the destination for the dates of the flight (departure and return date) using the hotel_search_tool. Then look for attractions in the destination using the city_attractions_tool.
Then create a map of the trip using the map_plotting_tool. Then calculate the cost of the trip using the calculator_tool. Then send an email to the user with the itinerary details using the gmail_itinerary_tool 
after the user is done with the conversation asking them for their email.
"""

# %%
def create_agent(system_prompt):
    model = ChatOpenAI(model="gpt-4-turbo")
    tools = initialize_tools()
    return create_react_agent(model, tools=tools, state_modifier=system_prompt, debug=True)

# %%
agent = create_agent(system_prompt)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from langchain.callbacks import get_openai_callback

messages = [("user", "my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.")]

with get_openai_callback() as cb:
    response = agent.invoke({"messages": messages})
    print(f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Total Cost (USD): ${cb.total_cost:.4f}")
# Out:
# [-1:checkpoint] State at the end of step -1:
# {'messages': []}
# [0:tasks] Starting 1 task for step 0:
# - __start__ -> {'messages': [('user',
#                'my name is sam controlman and i want to plan a holiday from '
#                '14th to 15th december. I like skiing and am flying from new '
#                'york.')]}
# [0:writes] Finished step 0 with writes to 1 channel:
# - messages -> [('user',
#   'my name is sam controlman and i want to plan a holiday from 14th to 15th '
#   'december. I like skiing and am flying from new york.')]
# [0:checkpoint] State at the end of step 0:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175')]}
# [1:tasks] Starting 1 task for step 1:
# - agent -> {'is_last_step': False,
#  'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175')],
#  'remaining_steps': 24}
# [1:writes] Finished step 1 with writes to 1 channel:
# - messages -> [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [1:checkpoint] State at the end of step 1:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [2:tasks] Starting 1 task for step 2:
# - tools -> {'is_last_step': False,
#  'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'remaining_steps': 23}
# [2:writes] Finished step 2 with writes to 1 channel:
# - messages -> [ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F')]
# [2:checkpoint] State at the end of step 2:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F')]}
# [3:tasks] Starting 1 task for step 3:
# - agent -> {'is_last_step': False,
#  'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F')],
#  'remaining_steps': 22}
# [3:writes] Finished step 3 with writes to 1 channel:
# - messages -> [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [3:checkpoint] State at the end of step 3:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [4:tasks] Starting 1 task for step 4:
# - tools -> {'is_last_step': False,
#  'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'remaining_steps': 21}
# [4:writes] Finished step 4 with writes to 1 channel:
# - messages -> [ToolMessage(content="Based on your preferences: 'skiing'\n\nHere are 3 recommended cities:\n\n1. Aspen, Colorado, USA\n   Matching aspects: Aspen is a premier destination for skiing and winter sports enthusiasts. \n        It features world-class ski resorts and stunning mountain views. \n        The town offers luxury shopping and fine dining experiences. \n        In summer, it's perfect for hiking, mountain biking, and outdoor concerts. \n        It's ideal for outdoor adventurers and luxury travelers.\n\n2. Banff, Canada\n   Matching aspects: Banff is a haven for outdoor enthusiasts, nestled in the Canadian Rockies. \n        It offers breathtaking mountain views, turquoise lakes like Lake Louise, and abundant wildlife. \n        Visitors can enjoy activities like hiking, skiing, and canoeing. \n        The charming town of Banff features cozy lodges and local shops. \n        It's ideal for nature lovers and adventure seekers.\n\n3. Queenstown, New Zealand\n   Matching aspects: Queenstown is an adventure capital surrounded by stunning natural beauty. \n        It offers activities like bungee jumping, skydiving, and jet boating. \n        Visitors can explore Lake Wakatipu, nearby wineries, and mountain trails. \n        The town's vibrant atmosphere includes cozy cafes and lively bars. \n        It's perfect for thrill-seekers and nature enthusiasts.\n", name='city_recommendation_tool', tool_call_id='call_25vOPnPsRT4oCPeNmBKFP2xC')]
# [4:checkpoint] State at the end of step 4:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Based on your preferences: 'skiing'\n\nHere are 3 recommended cities:\n\n1. Aspen, Colorado, USA\n   Matching aspects: Aspen is a premier destination for skiing and winter sports enthusiasts. \n        It features world-class ski resorts and stunning mountain views. \n        The town offers luxury shopping and fine dining experiences. \n        In summer, it's perfect for hiking, mountain biking, and outdoor concerts. \n        It's ideal for outdoor adventurers and luxury travelers.\n\n2. Banff, Canada\n   Matching aspects: Banff is a haven for outdoor enthusiasts, nestled in the Canadian Rockies. \n        It offers breathtaking mountain views, turquoise lakes like Lake Louise, and abundant wildlife. \n        Visitors can enjoy activities like hiking, skiing, and canoeing. \n        The charming town of Banff features cozy lodges and local shops. \n        It's ideal for nature lovers and adventure seekers.\n\n3. Queenstown, New Zealand\n   Matching aspects: Queenstown is an adventure capital surrounded by stunning natural beauty. \n        It offers activities like bungee jumping, skydiving, and jet boating. \n        Visitors can explore Lake Wakatipu, nearby wineries, and mountain trails. \n        The town's vibrant atmosphere includes cozy cafes and lively bars. \n        It's perfect for thrill-seekers and nature enthusiasts.\n", name='city_recommendation_tool', id='a5ee93d4-b1f3-4572-85f0-1e4f7aab9a6a', tool_call_id='call_25vOPnPsRT4oCPeNmBKFP2xC')]}
# [5:tasks] Starting 1 task for step 5:
# - agent -> {'is_last_step': False,
#  'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Based on your preferences: 'skiing'\n\nHere are 3 recommended cities:\n\n1. Aspen, Colorado, USA\n   Matching aspects: Aspen is a premier destination for skiing and winter sports enthusiasts. \n        It features world-class ski resorts and stunning mountain views. \n        The town offers luxury shopping and fine dining experiences. \n        In summer, it's perfect for hiking, mountain biking, and outdoor concerts. \n        It's ideal for outdoor adventurers and luxury travelers.\n\n2. Banff, Canada\n   Matching aspects: Banff is a haven for outdoor enthusiasts, nestled in the Canadian Rockies. \n        It offers breathtaking mountain views, turquoise lakes like Lake Louise, and abundant wildlife. \n        Visitors can enjoy activities like hiking, skiing, and canoeing. \n        The charming town of Banff features cozy lodges and local shops. \n        It's ideal for nature lovers and adventure seekers.\n\n3. Queenstown, New Zealand\n   Matching aspects: Queenstown is an adventure capital surrounded by stunning natural beauty. \n        It offers activities like bungee jumping, skydiving, and jet boating. \n        Visitors can explore Lake Wakatipu, nearby wineries, and mountain trails. \n        The town's vibrant atmosphere includes cozy cafes and lively bars. \n        It's perfect for thrill-seekers and nature enthusiasts.\n", name='city_recommendation_tool', id='a5ee93d4-b1f3-4572-85f0-1e4f7aab9a6a', tool_call_id='call_25vOPnPsRT4oCPeNmBKFP2xC')],
#  'remaining_steps': 20}
# [5:writes] Finished step 5 with writes to 1 channel:
# - messages -> [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'function': {'arguments': '{"input_str":"{\\"departure_airport\\":\\"JFK\\",\\"arrival_airport\\":\\"ASE\\",\\"departure_date\\":\\"2024-12-14\\",\\"return_date\\":\\"2024-12-15\\"}"}', 'name': 'flight_search_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 1445, 'total_tokens': 1496, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2a12069c-fdb2-49ef-ab1e-5ebfca1f01c7-0', tool_calls=[{'name': 'flight_search_tool', 'args': {'input_str': '{"departure_airport":"JFK","arrival_airport":"ASE","departure_date":"2024-12-14","return_date":"2024-12-15"}'}, 'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1445, 'output_tokens': 51, 'total_tokens': 1496, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [5:checkpoint] State at the end of step 5:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Based on your preferences: 'skiing'\n\nHere are 3 recommended cities:\n\n1. Aspen, Colorado, USA\n   Matching aspects: Aspen is a premier destination for skiing and winter sports enthusiasts. \n        It features world-class ski resorts and stunning mountain views. \n        The town offers luxury shopping and fine dining experiences. \n        In summer, it's perfect for hiking, mountain biking, and outdoor concerts. \n        It's ideal for outdoor adventurers and luxury travelers.\n\n2. Banff, Canada\n   Matching aspects: Banff is a haven for outdoor enthusiasts, nestled in the Canadian Rockies. \n        It offers breathtaking mountain views, turquoise lakes like Lake Louise, and abundant wildlife. \n        Visitors can enjoy activities like hiking, skiing, and canoeing. \n        The charming town of Banff features cozy lodges and local shops. \n        It's ideal for nature lovers and adventure seekers.\n\n3. Queenstown, New Zealand\n   Matching aspects: Queenstown is an adventure capital surrounded by stunning natural beauty. \n        It offers activities like bungee jumping, skydiving, and jet boating. \n        Visitors can explore Lake Wakatipu, nearby wineries, and mountain trails. \n        The town's vibrant atmosphere includes cozy cafes and lively bars. \n        It's perfect for thrill-seekers and nature enthusiasts.\n", name='city_recommendation_tool', id='a5ee93d4-b1f3-4572-85f0-1e4f7aab9a6a', tool_call_id='call_25vOPnPsRT4oCPeNmBKFP2xC'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'function': {'arguments': '{"input_str":"{\\"departure_airport\\":\\"JFK\\",\\"arrival_airport\\":\\"ASE\\",\\"departure_date\\":\\"2024-12-14\\",\\"return_date\\":\\"2024-12-15\\"}"}', 'name': 'flight_search_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 1445, 'total_tokens': 1496, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2a12069c-fdb2-49ef-ab1e-5ebfca1f01c7-0', tool_calls=[{'name': 'flight_search_tool', 'args': {'input_str': '{"departure_airport":"JFK","arrival_airport":"ASE","departure_date":"2024-12-14","return_date":"2024-12-15"}'}, 'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1445, 'output_tokens': 51, 'total_tokens': 1496, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [6:tasks] Starting 1 task for step 6:
# - tools -> {'is_last_step': False,
#  'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Based on your preferences: 'skiing'\n\nHere are 3 recommended cities:\n\n1. Aspen, Colorado, USA\n   Matching aspects: Aspen is a premier destination for skiing and winter sports enthusiasts. \n        It features world-class ski resorts and stunning mountain views. \n        The town offers luxury shopping and fine dining experiences. \n        In summer, it's perfect for hiking, mountain biking, and outdoor concerts. \n        It's ideal for outdoor adventurers and luxury travelers.\n\n2. Banff, Canada\n   Matching aspects: Banff is a haven for outdoor enthusiasts, nestled in the Canadian Rockies. \n        It offers breathtaking mountain views, turquoise lakes like Lake Louise, and abundant wildlife. \n        Visitors can enjoy activities like hiking, skiing, and canoeing. \n        The charming town of Banff features cozy lodges and local shops. \n        It's ideal for nature lovers and adventure seekers.\n\n3. Queenstown, New Zealand\n   Matching aspects: Queenstown is an adventure capital surrounded by stunning natural beauty. \n        It offers activities like bungee jumping, skydiving, and jet boating. \n        Visitors can explore Lake Wakatipu, nearby wineries, and mountain trails. \n        The town's vibrant atmosphere includes cozy cafes and lively bars. \n        It's perfect for thrill-seekers and nature enthusiasts.\n", name='city_recommendation_tool', id='a5ee93d4-b1f3-4572-85f0-1e4f7aab9a6a', tool_call_id='call_25vOPnPsRT4oCPeNmBKFP2xC'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'function': {'arguments': '{"input_str":"{\\"departure_airport\\":\\"JFK\\",\\"arrival_airport\\":\\"ASE\\",\\"departure_date\\":\\"2024-12-14\\",\\"return_date\\":\\"2024-12-15\\"}"}', 'name': 'flight_search_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 1445, 'total_tokens': 1496, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2a12069c-fdb2-49ef-ab1e-5ebfca1f01c7-0', tool_calls=[{'name': 'flight_search_tool', 'args': {'input_str': '{"departure_airport":"JFK","arrival_airport":"ASE","departure_date":"2024-12-14","return_date":"2024-12-15"}'}, 'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1445, 'output_tokens': 51, 'total_tokens': 1496, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'remaining_steps': 19}
# [6:writes] Finished step 6 with writes to 1 channel:
# - messages -> [ToolMessage(content='Found the following flights:\n- American: $628, Duration: 488min (2024-12-14 08:05 - 2024-12-14 11:26)\n', name='flight_search_tool', tool_call_id='call_J8Z8Y19A5sS5LC8vdkgF4Wf7')]
# [6:checkpoint] State at the end of step 6:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Based on your preferences: 'skiing'\n\nHere are 3 recommended cities:\n\n1. Aspen, Colorado, USA\n   Matching aspects: Aspen is a premier destination for skiing and winter sports enthusiasts. \n        It features world-class ski resorts and stunning mountain views. \n        The town offers luxury shopping and fine dining experiences. \n        In summer, it's perfect for hiking, mountain biking, and outdoor concerts. \n        It's ideal for outdoor adventurers and luxury travelers.\n\n2. Banff, Canada\n   Matching aspects: Banff is a haven for outdoor enthusiasts, nestled in the Canadian Rockies. \n        It offers breathtaking mountain views, turquoise lakes like Lake Louise, and abundant wildlife. \n        Visitors can enjoy activities like hiking, skiing, and canoeing. \n        The charming town of Banff features cozy lodges and local shops. \n        It's ideal for nature lovers and adventure seekers.\n\n3. Queenstown, New Zealand\n   Matching aspects: Queenstown is an adventure capital surrounded by stunning natural beauty. \n        It offers activities like bungee jumping, skydiving, and jet boating. \n        Visitors can explore Lake Wakatipu, nearby wineries, and mountain trails. \n        The town's vibrant atmosphere includes cozy cafes and lively bars. \n        It's perfect for thrill-seekers and nature enthusiasts.\n", name='city_recommendation_tool', id='a5ee93d4-b1f3-4572-85f0-1e4f7aab9a6a', tool_call_id='call_25vOPnPsRT4oCPeNmBKFP2xC'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'function': {'arguments': '{"input_str":"{\\"departure_airport\\":\\"JFK\\",\\"arrival_airport\\":\\"ASE\\",\\"departure_date\\":\\"2024-12-14\\",\\"return_date\\":\\"2024-12-15\\"}"}', 'name': 'flight_search_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 1445, 'total_tokens': 1496, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2a12069c-fdb2-49ef-ab1e-5ebfca1f01c7-0', tool_calls=[{'name': 'flight_search_tool', 'args': {'input_str': '{"departure_airport":"JFK","arrival_airport":"ASE","departure_date":"2024-12-14","return_date":"2024-12-15"}'}, 'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1445, 'output_tokens': 51, 'total_tokens': 1496, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Found the following flights:\n- American: $628, Duration: 488min (2024-12-14 08:05 - 2024-12-14 11:26)\n', name='flight_search_tool', id='09a7051c-e252-427c-8fc6-3e02d629f12a', tool_call_id='call_J8Z8Y19A5sS5LC8vdkgF4Wf7')]}
# [7:tasks] Starting 1 task for step 7:
# - agent -> {'is_last_step': False,
#  'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
# ...
# [13:checkpoint] State at the end of step 13:
# {'messages': [HumanMessage(content='my name is sam controlman and i want to plan a holiday from 14th to 15th december. I like skiing and am flying from new york.', additional_kwargs={}, response_metadata={}, id='9ec48f79-d56c-4d5d-aa97-76e048cc0175'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'function': {'arguments': '{"username":"sam controlman","preferences":"skiing","hometown":"New York"}', 'name': 'user_info_and_preferences_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 1094, 'total_tokens': 1124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-29bef550-0558-4b43-8e73-d4b9f900e43d-0', tool_calls=[{'name': 'user_info_and_preferences_tool', 'args': {'username': 'sam controlman', 'preferences': 'skiing', 'hometown': 'New York'}, 'id': 'call_eBpY48XRkQhYj3DQPg11lZ6F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1094, 'output_tokens': 30, 'total_tokens': 1124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Preferences stored successfully for sam controlman: skiing', name='user_info_and_preferences_tool', id='738657dd-fa4e-4e1c-93c5-45062bdd0ed3', tool_call_id='call_eBpY48XRkQhYj3DQPg11lZ6F'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'function': {'arguments': '{"user_preferences":"skiing"}', 'name': 'city_recommendation_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1144, 'total_tokens': 1162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-634a42b0-868d-4c60-8de1-ded6a8719052-0', tool_calls=[{'name': 'city_recommendation_tool', 'args': {'user_preferences': 'skiing'}, 'id': 'call_25vOPnPsRT4oCPeNmBKFP2xC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1144, 'output_tokens': 18, 'total_tokens': 1162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Based on your preferences: 'skiing'\n\nHere are 3 recommended cities:\n\n1. Aspen, Colorado, USA\n   Matching aspects: Aspen is a premier destination for skiing and winter sports enthusiasts. \n        It features world-class ski resorts and stunning mountain views. \n        The town offers luxury shopping and fine dining experiences. \n        In summer, it's perfect for hiking, mountain biking, and outdoor concerts. \n        It's ideal for outdoor adventurers and luxury travelers.\n\n2. Banff, Canada\n   Matching aspects: Banff is a haven for outdoor enthusiasts, nestled in the Canadian Rockies. \n        It offers breathtaking mountain views, turquoise lakes like Lake Louise, and abundant wildlife. \n        Visitors can enjoy activities like hiking, skiing, and canoeing. \n        The charming town of Banff features cozy lodges and local shops. \n        It's ideal for nature lovers and adventure seekers.\n\n3. Queenstown, New Zealand\n   Matching aspects: Queenstown is an adventure capital surrounded by stunning natural beauty. \n        It offers activities like bungee jumping, skydiving, and jet boating. \n        Visitors can explore Lake Wakatipu, nearby wineries, and mountain trails. \n        The town's vibrant atmosphere includes cozy cafes and lively bars. \n        It's perfect for thrill-seekers and nature enthusiasts.\n", name='city_recommendation_tool', id='a5ee93d4-b1f3-4572-85f0-1e4f7aab9a6a', tool_call_id='call_25vOPnPsRT4oCPeNmBKFP2xC'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'function': {'arguments': '{"input_str":"{\\"departure_airport\\":\\"JFK\\",\\"arrival_airport\\":\\"ASE\\",\\"departure_date\\":\\"2024-12-14\\",\\"return_date\\":\\"2024-12-15\\"}"}', 'name': 'flight_search_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 1445, 'total_tokens': 1496, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2a12069c-fdb2-49ef-ab1e-5ebfca1f01c7-0', tool_calls=[{'name': 'flight_search_tool', 'args': {'input_str': '{"departure_airport":"JFK","arrival_airport":"ASE","departure_date":"2024-12-14","return_date":"2024-12-15"}'}, 'id': 'call_J8Z8Y19A5sS5LC8vdkgF4Wf7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1445, 'output_tokens': 51, 'total_tokens': 1496, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Found the following flights:\n- American: $628, Duration: 488min (2024-12-14 08:05 - 2024-12-14 11:26)\n', name='flight_search_tool', id='09a7051c-e252-427c-8fc6-3e02d629f12a', tool_call_id='call_J8Z8Y19A5sS5LC8vdkgF4Wf7'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_wjnNN9rJi9jAiJSnwjMcH88E', 'function': {'arguments': '{"destination":"Aspen","check_in_date":"2024-12-14","check_out_date":"2024-12-15"}', 'name': 'hotel_search_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 1545, 'total_tokens': 1584, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-dd8566be-9f5c-4573-952a-808f07392c0b-0', tool_calls=[{'name': 'hotel_search_tool', 'args': {'destination': 'Aspen', 'check_in_date': '2024-12-14', 'check_out_date': '2024-12-15'}, 'id': 'call_wjnNN9rJi9jAiJSnwjMcH88E', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1545, 'output_tokens': 39, 'total_tokens': 1584, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Found the following hotels in Aspen:\n\n🏨 Aspen Mountain Lodge 211\n   Price: $368 total for your stay\n   Rating: 4.0627456/5 (51 reviews)\n   Description: ['Entire apartment', 'Sleeps 3', '1 bedroom', '1 bathroom', '2 beds', '596 sq ft']...\n\n   Address: 39.1917839050293, -106.82592010498047\n\n🏨 Aspen Mountain Lodge 310\n   Price: $374 total for your stay\n   Rating: 4.2617645/5 (34 reviews)\n   Description: ['Sleeps 3', '1 bedroom', '1 bathroom', '2 beds', '296 sq ft']...\n\n   Address: 39.19166946411133, -106.82581329345703\n\n🏨 Aspen Mountain Lodge 300\n   Price: $374 total for your stay\n   Rating: 3.857143/5 (7 reviews)\n   Description: ['Sleeps 3', '1 bedroom', '1 bathroom', '2 beds']...\n\n   Address: 39.191741943359375, -106.82593536376953\n\n🏨 Aspen Mountain Lodge 309\n   Price: $374 total for your stay\n   Rating: 4.363889/5 (36 reviews)\n   Description: ['Sleeps 4', '1 bedroom', '1 bathroom', '2 beds', '296 sq ft']...\n\n   Address: 39.19166564941406, -106.8257827758789\n\n🏨 Aspen Mountain Lodge 302\n   Price: $374 total for your stay\n   Rating: 4.6322584/5 (31 reviews)\n   Description: ['Sleeps 4', '1 bedroom', '1 bathroom', '2 beds', '296 sq ft']...\n\n   Address: 39.19173049926758, -106.82587432861328\n\n", name='hotel_search_tool', id='22611e44-ff41-4ec1-9890-8635aac073b6', tool_call_id='call_wjnNN9rJi9jAiJSnwjMcH88E'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_4tWJJZ5H2KeQkd7GFjyWIhsF', 'function': {'arguments': '{"city":"Aspen"}', 'name': 'city_attractions_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 2008, 'total_tokens': 2025, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_cfb5f9efa7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-0cbcdc3a-50ff-4ad3-bfcf-3be49e11999b-0', tool_calls=[{'name': 'city_attractions_tool', 'args': {'city': 'Aspen'}, 'id': 'call_4tWJJZ5H2KeQkd7GFjyWIhsF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2008, 'output_tokens': 17, 'total_tokens': 2025, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Attractions in Aspen:\n\n- Maroon Bells\n  Category: Adventure\n  Description: Stunning mountain peaks with picturesque hiking and photography opportunities.\n  Coordinates: 39.1664° N, -106.8793° E\n\n- Aspen Mountain\n  Category: Sport\n  Description: Popular for skiing and snowboarding with breathtaking views.\n  Coordinates: 39.1680° N, -106.8206° E\n\n- Independence Pass\n  Category: Adventure\n  Description: A scenic mountain pass with dramatic vistas and hiking trails.\n\n- John Denver Sanctuary\n  Category: Experiences\n  Description: A peaceful park with poetry-engraved rocks and serene landscapes.\n  Coordinates: 39.1924° N, -106.8163° E\n\n- Aspen Art Museum\n  Category: Experiences\n  Description: Contemporary art exhibits in a sleek, modern space.\n  Coordinates: 39.1883° N, -106.8165° E\n\n- Snowmass Village\n  Category: Sport\n  Description: Known for family-friendly skiing and year-round outdoor activities.\n  Coordinates: 39.1857° N, -106.9449° E\n\n- Aspen Music Festival\n  Category: Experiences\n  Description: Renowned classical music performances during the summer season.\n\n- Buttermilk Mountain\n  Category: Sport\n  Description: A ski resort famous for hosting the Winter X Games.\n\n- Rio Grande Trail\n  Category: Adventure\n  Description: A long trail for biking, walking, and scenic exploration.\n  Coordinates: 39.1924° N, -106.8171° E\n\n- Ashcroft Ghost Town\n  Category: Historical\n  Description: A preserved mining town offering a glimpse into Aspen’s history.\n  Coordinates: 39.0556° N, -106.7996° E\n', name='city_attractions_tool', id='45734c9b-3496-4f82-920e-bcf27d7480e0', tool_call_id='call_4tWJJZ5H2KeQkd7GFjyWIhsF'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_JLZpDIXKhF5VWJ7vWkvBWfJg', 'function': {'arguments': '{"expression":"628 + 368"}', 'name': 'calculator_tool'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 2417, 'total_tokens': 2435, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-69ff195a-827d-429c-b6e4-a76a90636db9-0', tool_calls=[{'name': 'calculator_tool', 'args': {'expression': '628 + 368'}, 'id': 'call_JLZpDIXKhF5VWJ7vWkvBWfJg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2417, 'output_tokens': 18, 'total_tokens': 2435, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='996', name='calculator_tool', id='36129321-dc9a-4175-8283-b5921b0a42a2', tool_call_id='call_JLZpDIXKhF5VWJ7vWkvBWfJg'),
#               AIMessage(content="Here is your holiday plan summary for Aspen from December 14th to December 15th, 2024:\n\n### Flight Details\n- **Airline:** American\n- **Cost:** $628\n- **Departure:** December 14th, 2024, 08:05 from JFK\n- **Arrival:** December 14th, 2024, 11:26 in Aspen (ASE)\n- **Return:** December 15th, 2024\n\n### Hotel Details\n- **Hotel:** Aspen Mountain Lodge 211\n- **Cost:** $368\n- **Stay Duration:** 1 night\n- **Rating:** 4.06/5\n- **Features:** Entire apartment, sleeps 3, 1 bedroom, 1 bathroom, 2 beds, 596 sq ft\n\n### Top Attractions in Aspen\n1. **Maroon Bells** - Stunning mountain peaks with picturesque hiking and photography opportunities.\n2. **Aspen Mountain** - Popular for skiing and snowboarding with breathtaking views.\n3. **Independence Pass** - A scenic mountain pass with dramatic vistas and hiking trails.\n4. **John Denver Sanctuary** - A peaceful park with poetry-engraved rocks and serene landscapes.\n5. **Aspen Art Museum** - Contemporary art exhibits in a sleek, modern space.\n6. **Snowmass Village** - Known for family-friendly skiing and year-round outdoor activities.\n7. **Aspen Music Festival** - Renowned classical music performances during the summer season.\n8. **Buttermilk Mountain** - A ski resort famous for hosting the Winter X Games.\n9. **Rio Grande Trail** - A long trail for biking, walking, and scenic exploration.\n10. **Ashcroft Ghost Town** - A preserved mining town offering a glimpse into Aspen’s history.\n\n### Total Cost\n- **Total:** $996\n   - Flight: $628\n   - Hotel: $368\n\nIf there's anything else you'd like to add or modify in your plan, please let me know!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 416, 'prompt_tokens': 2444, 'total_tokens': 2860, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo-2024-04-09', 'system_fingerprint': 'fp_0f602ebbda', 'finish_reason': 'stop', 'logprobs': None}, id='run-81c921eb-76e4-48ca-9873-572e66f7d49a-0', usage_metadata={'input_tokens': 2444, 'output_tokens': 416, 'total_tokens': 2860, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Total Tokens: 12686
# Prompt Tokens: 12097
# Completion Tokens: 589
# Total Cost (USD): $0.1386
